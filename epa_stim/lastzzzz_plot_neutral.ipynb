# %%
# -*- coding: utf-8 -*-
"""
Created on Fri Nov  9 19:40:04 2018

@author: mslip
"""
import glob
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
plt.rcParams["font.family"] = "Arial"

tsv_files = glob.glob('*.tsv')
#print csv_files which is a list of filenames
print(tsv_files)
 
#intialize empty list that we will append dataframes to
subjects_df = []

#write a for loop that will go through each of the file name through globbing and the end result will be the list of dataframes
for filename in tsv_files:
    subjects_df.append(pd.read_csv(filename, delimiter='\t'))

stimulation_cond = [0,1,2] # tacs 1 -rTPJ, 2 - rDLPFC, 3 - Sync (both)
partner_cond     = [0,1,2] # 1 - neutral, 2 - 3/5, 3 - 5/5
offer_type_cond  = [0,1,2,3,4] # 1 - Keep $9, Give $1, 2 - Keep $8, Give $2,...
stim_location_means = []
subjects_stim_location_rejection_means = []
subjects_partner_type_rejection_means = []
subjects_offer_type_rejection_means = []
subjects_offer_type_partner_rejection_means = []
subjects_stim_location_partner_rejection_means = []
subjects_offer_type_stim_rejection_means = []

interaction_means_rtpj_neutral_1 = []
interaction_means_rtpj_low_1 = []
interaction_means_rtpj_high_1 = []
interaction_means_rtpj_neutral_5 = []
interaction_means_rtpj_low_5 = []
interaction_means_rtpj_high_5 = []
interaction_means_rdlpfc_neutral_1 = []
interaction_means_rdlpfc_low_1 = []
interaction_means_rdlpfc_high_1 = []
interaction_means_rdlpfc_neutral_5 = []
interaction_means_rdlpfc_low_5 = []
interaction_means_rdlpfc_high_5 = []
interaction_means_sync_neutral_1 = []
interaction_means_sync_low_1 = []
interaction_means_sync_high_1 = []
interaction_means_sync_neutral_5 = []
interaction_means_sync_low_5 = []
interaction_means_sync_high_5 = []

interaction_means_rtpj_neutral_2 = []
interaction_means_rtpj_low_2 = []
interaction_means_rtpj_high_2 = []
interaction_means_rdlpfc_neutral_2 = []
interaction_means_rdlpfc_low_2 = []
interaction_means_rdlpfc_high_2 = []
interaction_means_sync_neutral_2 = []
interaction_means_sync_low_2 = []
interaction_means_sync_high_2 = []

interaction_means_rtpj_neutral_3 = []
interaction_means_rtpj_low_3 = []
interaction_means_rtpj_high_3 = []
interaction_means_rdlpfc_neutral_3 = []
interaction_means_rdlpfc_low_3 = []
interaction_means_rdlpfc_high_3 = []
interaction_means_sync_neutral_3 = []
interaction_means_sync_low_3 = []
interaction_means_sync_high_3 = []

interaction_means_rtpj_neutral_4 = []
interaction_means_rtpj_low_4 = []
interaction_means_rtpj_high_4 = []
interaction_means_rdlpfc_neutral_4 = []
interaction_means_rdlpfc_low_4 = []
interaction_means_rdlpfc_high_4 = []
interaction_means_sync_neutral_4 = []
interaction_means_sync_low_4 = []
interaction_means_sync_high_4 = []

for subject_ind in range(12):
##    for stim_ind in range(3):
##        for partner_ind in range(3):
##            for offer_ind in range(5):
    perm_mean_rtpj_neutral_1 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([1])
                        & subjects_df[subject_ind].PartnerType.isin([1])
                        & subjects_df[subject_ind].OfferType.isin([1])]['PlayerChoice'].mean()
   
    perm_mean_rtpj_low_1 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([1])
                        & subjects_df[subject_ind].PartnerType.isin([2]) 
                        & subjects_df[subject_ind].OfferType.isin([1])]['PlayerChoice'].mean()
    
    perm_mean_rtpj_high_1 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([1])
                        & subjects_df[subject_ind].PartnerType.isin([3]) 
                        & subjects_df[subject_ind].OfferType.isin([1])]['PlayerChoice'].mean()
    
    perm_mean_rdlpfc_neutral_1 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([2])
                        & subjects_df[subject_ind].PartnerType.isin([1]) 
                        & subjects_df[subject_ind].OfferType.isin([1])]['PlayerChoice'].mean()
    
    perm_mean_rdlpfc_low_1 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([2])
                        & subjects_df[subject_ind].PartnerType.isin([2]) 
                        & subjects_df[subject_ind].OfferType.isin([1])]['PlayerChoice'].mean()
    
    perm_mean_rdlpfc_high_1 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([2])
                        & subjects_df[subject_ind].PartnerType.isin([3]) 
                        & subjects_df[subject_ind].OfferType.isin([1])]['PlayerChoice'].mean()
    
    perm_mean_sync_neutral_1 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([3])
                        & subjects_df[subject_ind].PartnerType.isin([1]) 
                        & subjects_df[subject_ind].OfferType.isin([1])]['PlayerChoice'].mean()
    
    perm_mean_sync_low_1 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([3])
                        & subjects_df[subject_ind].PartnerType.isin([2]) 
                        & subjects_df[subject_ind].OfferType.isin([1])]['PlayerChoice'].mean()
    
    perm_mean_sync_high_1 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([3])
                        & subjects_df[subject_ind].PartnerType.isin([3]) 
                        & subjects_df[subject_ind].OfferType.isin([1])]['PlayerChoice'].mean()
    
    
    
    
    
    perm_mean_rtpj_neutral_2 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([1])
                        & subjects_df[subject_ind].PartnerType.isin([1])
                        & subjects_df[subject_ind].OfferType.isin([2])]['PlayerChoice'].mean()
   
    perm_mean_rtpj_low_2 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([1])
                        & subjects_df[subject_ind].PartnerType.isin([2]) 
                        & subjects_df[subject_ind].OfferType.isin([2])]['PlayerChoice'].mean()
    
    perm_mean_rtpj_high_2 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([1])
                        & subjects_df[subject_ind].PartnerType.isin([3]) 
                        & subjects_df[subject_ind].OfferType.isin([2])]['PlayerChoice'].mean()
    
    perm_mean_rdlpfc_neutral_2 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([2])
                        & subjects_df[subject_ind].PartnerType.isin([1]) 
                        & subjects_df[subject_ind].OfferType.isin([2])]['PlayerChoice'].mean()
    
    perm_mean_rdlpfc_low_2 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([2])
                        & subjects_df[subject_ind].PartnerType.isin([2]) 
                        & subjects_df[subject_ind].OfferType.isin([2])]['PlayerChoice'].mean()
    
    perm_mean_rdlpfc_high_2 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([2])
                        & subjects_df[subject_ind].PartnerType.isin([3]) 
                        & subjects_df[subject_ind].OfferType.isin([2])]['PlayerChoice'].mean()
    
    perm_mean_sync_neutral_2 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([3])
                        & subjects_df[subject_ind].PartnerType.isin([1]) 
                        & subjects_df[subject_ind].OfferType.isin([2])]['PlayerChoice'].mean()
    
    perm_mean_sync_low_2 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([3])
                        & subjects_df[subject_ind].PartnerType.isin([2]) 
                        & subjects_df[subject_ind].OfferType.isin([2])]['PlayerChoice'].mean()
    
    perm_mean_sync_high_2 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([3])
                        & subjects_df[subject_ind].PartnerType.isin([3]) 
                        & subjects_df[subject_ind].OfferType.isin([2])]['PlayerChoice'].mean()
    
    perm_mean_rtpj_neutral_3 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([1])
                        & subjects_df[subject_ind].PartnerType.isin([1])
                        & subjects_df[subject_ind].OfferType.isin([3])]['PlayerChoice'].mean()
   
    perm_mean_rtpj_low_3 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([1])
                        & subjects_df[subject_ind].PartnerType.isin([2]) 
                        & subjects_df[subject_ind].OfferType.isin([3])]['PlayerChoice'].mean()
    
    perm_mean_rtpj_high_3 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([1])
                        & subjects_df[subject_ind].PartnerType.isin([3]) 
                        & subjects_df[subject_ind].OfferType.isin([3])]['PlayerChoice'].mean()
    
    perm_mean_rdlpfc_neutral_3 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([2])
                        & subjects_df[subject_ind].PartnerType.isin([1]) 
                        & subjects_df[subject_ind].OfferType.isin([3])]['PlayerChoice'].mean()
    
    perm_mean_rdlpfc_low_3 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([2])
                        & subjects_df[subject_ind].PartnerType.isin([2]) 
                        & subjects_df[subject_ind].OfferType.isin([3])]['PlayerChoice'].mean()
    
    perm_mean_rdlpfc_high_3 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([2])
                        & subjects_df[subject_ind].PartnerType.isin([3]) 
                        & subjects_df[subject_ind].OfferType.isin([3])]['PlayerChoice'].mean()
    
    perm_mean_sync_neutral_3 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([3])
                        & subjects_df[subject_ind].PartnerType.isin([1]) 
                        & subjects_df[subject_ind].OfferType.isin([3])]['PlayerChoice'].mean()
    
    perm_mean_sync_low_3 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([3])
                        & subjects_df[subject_ind].PartnerType.isin([2]) 
                        & subjects_df[subject_ind].OfferType.isin([3])]['PlayerChoice'].mean()
    
    perm_mean_sync_high_3 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([3])
                        & subjects_df[subject_ind].PartnerType.isin([3]) 
                        & subjects_df[subject_ind].OfferType.isin([3])]['PlayerChoice'].mean()
    
    perm_mean_rtpj_neutral_4 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([1])
                        & subjects_df[subject_ind].PartnerType.isin([1])
                        & subjects_df[subject_ind].OfferType.isin([4])]['PlayerChoice'].mean()
   
    perm_mean_rtpj_low_4 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([1])
                        & subjects_df[subject_ind].PartnerType.isin([2]) 
                        & subjects_df[subject_ind].OfferType.isin([4])]['PlayerChoice'].mean()
    
    perm_mean_rtpj_high_4 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([1])
                        & subjects_df[subject_ind].PartnerType.isin([3]) 
                        & subjects_df[subject_ind].OfferType.isin([4])]['PlayerChoice'].mean()
    
    perm_mean_rdlpfc_neutral_4 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([2])
                        & subjects_df[subject_ind].PartnerType.isin([1]) 
                        & subjects_df[subject_ind].OfferType.isin([4])]['PlayerChoice'].mean()
    
    perm_mean_rdlpfc_low_4 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([2])
                        & subjects_df[subject_ind].PartnerType.isin([2]) 
                        & subjects_df[subject_ind].OfferType.isin([4])]['PlayerChoice'].mean()
    
    perm_mean_rdlpfc_high_4 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([2])
                        & subjects_df[subject_ind].PartnerType.isin([3]) 
                        & subjects_df[subject_ind].OfferType.isin([4])]['PlayerChoice'].mean()
    
    perm_mean_sync_neutral_4 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([3])
                        & subjects_df[subject_ind].PartnerType.isin([1]) 
                        & subjects_df[subject_ind].OfferType.isin([4])]['PlayerChoice'].mean()
    
    perm_mean_sync_low_4 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([3])
                        & subjects_df[subject_ind].PartnerType.isin([2]) 
                        & subjects_df[subject_ind].OfferType.isin([4])]['PlayerChoice'].mean()
    
    perm_mean_sync_high_4 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([3])
                        & subjects_df[subject_ind].PartnerType.isin([3]) 
                        & subjects_df[subject_ind].OfferType.isin([4])]['PlayerChoice'].mean()
    
    perm_mean_rtpj_neutral_5 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([1])
                        & subjects_df[subject_ind].PartnerType.isin([1]) 
                        & subjects_df[subject_ind].OfferType.isin([5])]['PlayerChoice'].mean()
   
    perm_mean_rtpj_low_5 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([1])
                        & subjects_df[subject_ind].PartnerType.isin([2]) 
                        & subjects_df[subject_ind].OfferType.isin([5])]['PlayerChoice'].mean()
    
    perm_mean_rtpj_high_5 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([1])
                        & subjects_df[subject_ind].PartnerType.isin([3]) 
                        & subjects_df[subject_ind].OfferType.isin([5])]['PlayerChoice'].mean()
    
    perm_mean_rdlpfc_neutral_5 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([2])
                        & subjects_df[subject_ind].PartnerType.isin([1]) 
                        & subjects_df[subject_ind].OfferType.isin([5])]['PlayerChoice'].mean()
    
    perm_mean_rdlpfc_low_5 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([2])
                        & subjects_df[subject_ind].PartnerType.isin([2]) 
                        & subjects_df[subject_ind].OfferType.isin([5])]['PlayerChoice'].mean()
    
    perm_mean_rdlpfc_high_5 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([2])
                        & subjects_df[subject_ind].PartnerType.isin([3]) 
                        & subjects_df[subject_ind].OfferType.isin([5])]['PlayerChoice'].mean()
    
    perm_mean_sync_neutral_5 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([3])
                        & subjects_df[subject_ind].PartnerType.isin([1]) 
                        & subjects_df[subject_ind].OfferType.isin([5])]['PlayerChoice'].mean()
    
    perm_mean_sync_low_5 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([3])
                        & subjects_df[subject_ind].PartnerType.isin([2]) 
                        & subjects_df[subject_ind].OfferType.isin([5])]['PlayerChoice'].mean()
    
    perm_mean_sync_high_5 = subjects_df[subject_ind][subjects_df[subject_ind].StimulationCondition.isin([3])
                        & subjects_df[subject_ind].PartnerType.isin([3]) 
                        & subjects_df[subject_ind].OfferType.isin([5])]['PlayerChoice'].mean()
    
    interaction_means_rtpj_neutral_1.append(perm_mean_rtpj_neutral_1)
    interaction_means_rtpj_low_1.append(perm_mean_rtpj_low_1)
    interaction_means_rtpj_high_1.append(perm_mean_rtpj_high_1)
    interaction_means_rtpj_neutral_5.append(perm_mean_rtpj_neutral_5)
    interaction_means_rtpj_low_5.append(perm_mean_rtpj_low_5)
    interaction_means_rtpj_high_5.append(perm_mean_rtpj_high_5)
    
    interaction_means_rdlpfc_neutral_1.append(perm_mean_rdlpfc_neutral_1)
    interaction_means_rdlpfc_low_1.append(perm_mean_rdlpfc_low_1)
    interaction_means_rdlpfc_high_1.append(perm_mean_rdlpfc_high_1)
    interaction_means_rdlpfc_neutral_5.append(perm_mean_rdlpfc_neutral_5)
    interaction_means_rdlpfc_low_5.append(perm_mean_rdlpfc_low_5)
    interaction_means_rdlpfc_high_5.append(perm_mean_rdlpfc_high_5)
    
    interaction_means_sync_neutral_1.append(perm_mean_sync_neutral_1)
    interaction_means_sync_low_1.append(perm_mean_sync_low_1)
    interaction_means_sync_high_1.append(perm_mean_sync_high_1)
    interaction_means_sync_neutral_5.append(perm_mean_sync_neutral_5)
    interaction_means_sync_low_5.append(perm_mean_sync_low_5)
    interaction_means_sync_high_5.append(perm_mean_sync_high_5)
    
    
    
    interaction_means_rtpj_neutral_2.append(perm_mean_rtpj_neutral_2)
    interaction_means_rtpj_low_2.append(perm_mean_rtpj_low_2)
    interaction_means_rtpj_high_2.append(perm_mean_rtpj_high_2)
    interaction_means_rdlpfc_neutral_2.append(perm_mean_rdlpfc_neutral_2)
    interaction_means_rdlpfc_low_2.append(perm_mean_rdlpfc_low_2)
    interaction_means_rdlpfc_high_2.append(perm_mean_rdlpfc_high_2)
    interaction_means_sync_neutral_2.append(perm_mean_sync_neutral_2)
    interaction_means_sync_low_2.append(perm_mean_sync_low_2)
    interaction_means_sync_high_2.append(perm_mean_sync_high_2)
    
    
    interaction_means_rtpj_neutral_3.append(perm_mean_rtpj_neutral_3)
    interaction_means_rtpj_low_3.append(perm_mean_rtpj_low_3)
    interaction_means_rtpj_high_3.append(perm_mean_rtpj_high_3)
    interaction_means_rdlpfc_neutral_3.append(perm_mean_rdlpfc_neutral_3)
    interaction_means_rdlpfc_low_3.append(perm_mean_rdlpfc_low_3)
    interaction_means_rdlpfc_high_3.append(perm_mean_rdlpfc_high_3)
    interaction_means_sync_neutral_3.append(perm_mean_sync_neutral_3)
    interaction_means_sync_low_3.append(perm_mean_sync_low_3)
    interaction_means_sync_high_3.append(perm_mean_sync_high_3)
    
    
    interaction_means_rtpj_neutral_4.append(perm_mean_rtpj_neutral_4)
    interaction_means_rtpj_low_4.append(perm_mean_rtpj_low_4)
    interaction_means_rtpj_high_4.append(perm_mean_rtpj_high_4)
    interaction_means_rdlpfc_neutral_4.append(perm_mean_rdlpfc_neutral_4)
    interaction_means_rdlpfc_low_4.append(perm_mean_rdlpfc_low_4)
    interaction_means_rdlpfc_high_4.append(perm_mean_rdlpfc_high_4)
    interaction_means_sync_neutral_4.append(perm_mean_sync_neutral_4)
    interaction_means_sync_low_4.append(perm_mean_sync_low_4)
    interaction_means_sync_high_4.append(perm_mean_sync_high_4)
# Out:
# ['006_results.tsv', '009_results.tsv', '010_results.tsv', '011_results.tsv', '012_results.tsv', '013_results.tsv', '014_results.tsv', '015_results.tsv', '016_results.tsv', '019_results.tsv', '020_results.tsv', '021_results.tsv', '023_results.tsv']

# %%
from scipy import stats

def getData(data):
    allData = []
    myData = np.array(data)
    myDataFormatted = np.nan_to_num(myData)
    print ('standard error mean:'); print(stats.sem(myDataFormatted))
    print ('standard deviation:'); print(np.std(myDataFormatted))
    print ('Participant Mean: ')
    participant_means = sum(myDataFormatted)/len(myDataFormatted)
    print (participant_means)
    print ('\n')
# RTPJ NEUTRAL 1
getData(interaction_means_sync_low_4)
# Out:
# standard error mean:
# 0.04351941398892446
# standard deviation:
# 0.14433756729740643
# Participant Mean:
# 0.08333333333333333

# %%
#neutral, 1, 2, 3, 4, 5
N = 5
rtpj_means = (80.56, 72.22, 34.72, 0.00, 2.78)
rdlpfc_means = (77.78, 83.33, 33.33, 0.00, 11.11)
sync_means = (83.33, 77.78, 25.00, 0.00, 8.33)

# %%
rtpj_sem = (11.21, 11.48, 13.05, 0.00, 2.78)
rdlpfc_sem = (11.11, 11.24, 12.31, 0.00, 6.27)
sync_sem = (11.24, 11.11, 13.06, 0.00, 8.33)

# %%
ind = np.arange(N)  # the x locations for the groups
width = 0.25 

ig, ax = plt.subplots()
plot1 = ax.bar(ind, rtpj_means, width, color='g', yerr=rtpj_sem, edgecolor='black')
plot2 = ax.bar(ind + width, rdlpfc_means, width, color='b', yerr=rdlpfc_sem, edgecolor='black')
plot3 = ax.bar(ind + width + width, sync_means, width, color='r', yerr=sync_sem, edgecolor='black')

ax.set_ylabel('% Rejected')
ax.set_title('Neutral Fairness Rating', fontsize = 15, fontweight="bold")
ax.set_xticks(ind + width)
ax.set_xticklabels(('1/9', '2/8', '3/7', '4/6', '5/5'))
ax.legend((plot1[0], plot2[0], plot3[0]),('rTPJ', 'rDLPFC', 'Sync'), prop={'size': 8})
plt.locator_params(axis='y', nbins=5)
plt.ylim([0, 100])
ax.set_xlabel("Offer Type")
def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('neutral_rating.pdf', dpi=100)
plt.show()
