# %%
# -*- coding: utf-8 -*-
"""
Created on Sun Nov 11 18:51:17 2018

@author: mslip
"""
import glob
import pandas as pd
import numpy as np

ACTPJBLOCK = 1
ACDLPFCBLOCK = 2
ACSYNCBLOCK = 3
RNTPJBLOCK = 4
RNDLPFCBLOCK = 5
SHAMBLOCK = 6

tsv_files = glob.glob('*.tsv')
#print csv_files which is a list of filenames
print(tsv_files)
 
#intialize empty list that we will append dataframes to
subjects_df = []

#write a for loop that will go through each of the file name through globbing and the end result will be the list of dataframes
for filename in tsv_files:
    subjects_df.append(pd.read_csv(filename, delimiter='\t'))

subjects_means = []
subjects_game_type_transfer_means                = []
subjects_game_rtpj_rdlpfc_sham_transfer_means    = []
subjects_game_rn_rtpj_rdlpfc_sham_transfer_means = []
subjects_game_partner_transfer_means             = []
subjects_game_sync_sham_transfer_means = []
subjects_tacs_sync_rtpj_rdlpfc_sham_transfer_means = []
subjects_game_sync_rtpj_rdlpfc_sham_transfer_means = []
subjects_trns_sync_rtpj_rdlpfc_sham_transfer_means = []
subjects_game_transfer_means = []

    #    subject_means = []
mean_person_baseline_tACS_rTPJ = []
mean_person_punishment_tACS_rTPJ = []
    
mean_person_baseline_tACS_rDLPFC = []
mean_person_punishment_tACS_rDLPFC = []
    
mean_person_baseline_tACS_sync = []
mean_person_punishment_tACS_sync = []
    
mean_person_baseline_tRNS_rTPJ = []
mean_person_punishment_tRNS_rTPJ = []
    
mean_person_baseline_tRNS_rDLPFC = []
mean_person_punishment_tRNS_rDLPFC = []
    
mean_person_baseline_sham = []
mean_person_punishment_sham = []
    
mean_pc_baseline_tACS_rTPJ = []
mean_pc_punishment_tACS_rTPJ = []
    
mean_pc_baseline_tACS_rDLPFC = []
mean_pc_punishment_tACS_rDLPFC = []
    
mean_pc_baseline_tACS_sync = []
mean_pc_punishment_tACS_sync = []
    
mean_pc_baseline_tRNS_rTPJ = []
mean_pc_punishment_tRNS_rTPJ = []
    
mean_pc_baseline_tRNS_rDLPFC = []
mean_pc_punishment_tRNS_rDLPFC = []
    
mean_pc_baseline_sham = []
mean_pc_punishment_sham = []


stim_conds = [1,2,3,4,5,6]
game_conds = [1,2]
partner_conds = [1,2] # 1 - person
offer_conds = [1,2,3,4,5]

stim_cond_strings = ["tACS_rTPJ","tACS_rDLPFC","tACS_Sync","tRNS_rTPJ","tRNS_rDLPFC","Sham"]
game_cond_strings = ["Baseline","Punishment"]
partner_cond_strings = ["Person","PC"]

header = ""

for stim_ind in range(6):
        for game_ind in range(2):
            for partner_ind in range(2):
                    header = header + stim_cond_strings[stim_ind] + "_" + game_cond_strings[game_ind] + "_" + partner_cond_strings[partner_ind] + ", "

for subject_ind in range(13):
    

    person_baseline_tACS_rTPJ = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([1]) 
                            & subjects_df[subject_ind].GameType.isin([1])
                            & subjects_df[subject_ind].Condition.isin([1])]['PlayerChoice'].mean()
    
    person_punishment_tACS_rTPJ = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([1]) 
                            & subjects_df[subject_ind].GameType.isin([2])
                            & subjects_df[subject_ind].Condition.isin([1])]['PlayerChoice'].mean()
    
    person_baseline_tACS_rDLPFC = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([1]) 
                            & subjects_df[subject_ind].GameType.isin([1])
                            & subjects_df[subject_ind].Condition.isin([2])]['PlayerChoice'].mean()
    
    person_punishment_tACS_rDLPFC = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([1]) 
                            & subjects_df[subject_ind].GameType.isin([2])
                            & subjects_df[subject_ind].Condition.isin([2])]['PlayerChoice'].mean()
    
    person_baseline_tACS_sync = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([1]) 
                            & subjects_df[subject_ind].GameType.isin([1])
                            & subjects_df[subject_ind].Condition.isin([3])]['PlayerChoice'].mean()
    
    person_punishment_tACS_sync = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([1]) 
                            & subjects_df[subject_ind].GameType.isin([2])
                            & subjects_df[subject_ind].Condition.isin([3])]['PlayerChoice'].mean()
    
    person_baseline_tRNS_rTPJ = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([1]) 
                            & subjects_df[subject_ind].GameType.isin([1])
                            & subjects_df[subject_ind].Condition.isin([4])]['PlayerChoice'].mean()
    
    person_punishment_tRNS_rTPJ = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([1]) 
                            & subjects_df[subject_ind].GameType.isin([2])
                            & subjects_df[subject_ind].Condition.isin([4])]['PlayerChoice'].mean()
    
    person_baseline_tRNS_rDLPFC = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([1]) 
                            & subjects_df[subject_ind].GameType.isin([1])
                            & subjects_df[subject_ind].Condition.isin([5])]['PlayerChoice'].mean()
    
    person_punishment_tRNS_rDLPFC = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([1]) 
                            & subjects_df[subject_ind].GameType.isin([2])
                            & subjects_df[subject_ind].Condition.isin([5])]['PlayerChoice'].mean()
    
    person_baseline_sham = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([1]) 
                            & subjects_df[subject_ind].GameType.isin([1])
                            & subjects_df[subject_ind].Condition.isin([6])]['PlayerChoice'].mean()
    
    person_punishment_sham = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([1]) 
                            & subjects_df[subject_ind].GameType.isin([2])
                            & subjects_df[subject_ind].Condition.isin([6])]['PlayerChoice'].mean()
    
    pc_baseline_tACS_rTPJ = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([2]) 
                            & subjects_df[subject_ind].GameType.isin([1])
                            & subjects_df[subject_ind].Condition.isin([1])]['PlayerChoice'].mean()
    
    pc_punishment_tACS_rTPJ = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([2]) 
                            & subjects_df[subject_ind].GameType.isin([2])
                            & subjects_df[subject_ind].Condition.isin([1])]['PlayerChoice'].mean()
    
    pc_baseline_tACS_rDLPFC = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([2]) 
                            & subjects_df[subject_ind].GameType.isin([1])
                            & subjects_df[subject_ind].Condition.isin([2])]['PlayerChoice'].mean()
    
    pc_punishment_tACS_rDLPFC = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([2]) 
                            & subjects_df[subject_ind].GameType.isin([2])
                            & subjects_df[subject_ind].Condition.isin([2])]['PlayerChoice'].mean()
    
    pc_baseline_tACS_sync = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([2]) 
                            & subjects_df[subject_ind].GameType.isin([1])
                            & subjects_df[subject_ind].Condition.isin([3])]['PlayerChoice'].mean()
    
    pc_punishment_tACS_sync = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([2]) 
                            & subjects_df[subject_ind].GameType.isin([2])
                            & subjects_df[subject_ind].Condition.isin([3])]['PlayerChoice'].mean()
    
    pc_baseline_tRNS_rTPJ = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([2]) 
                            & subjects_df[subject_ind].GameType.isin([1])
                            & subjects_df[subject_ind].Condition.isin([4])]['PlayerChoice'].mean()
    
    pc_punishment_tRNS_rTPJ = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([2]) 
                            & subjects_df[subject_ind].GameType.isin([2])
                            & subjects_df[subject_ind].Condition.isin([4])]['PlayerChoice'].mean()
    
    pc_baseline_tRNS_rDLPFC = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([2]) 
                            & subjects_df[subject_ind].GameType.isin([1])
                            & subjects_df[subject_ind].Condition.isin([5])]['PlayerChoice'].mean()
    
    pc_punishment_tRNS_rDLPFC = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([2]) 
                            & subjects_df[subject_ind].GameType.isin([2])
                            & subjects_df[subject_ind].Condition.isin([5])]['PlayerChoice'].mean()
    
    pc_baseline_sham = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([2]) 
                            & subjects_df[subject_ind].GameType.isin([1])
                            & subjects_df[subject_ind].Condition.isin([6])]['PlayerChoice'].mean()
    
    pc_punishment_sham = subjects_df[subject_ind][subjects_df[subject_ind].OpponentType.isin([2]) 
                            & subjects_df[subject_ind].GameType.isin([2])
                            & subjects_df[subject_ind].Condition.isin([6])]['PlayerChoice'].mean()
    
    
    
    
    mean_person_baseline_tACS_rTPJ.append(person_baseline_tACS_rTPJ)
    mean_person_punishment_tACS_rTPJ.append(person_punishment_tACS_rTPJ)
    
    mean_person_baseline_tACS_rDLPFC.append(person_baseline_tACS_rDLPFC)
    mean_person_punishment_tACS_rDLPFC.append(person_punishment_tACS_rDLPFC)
    
    mean_person_baseline_tACS_sync.append(person_baseline_tACS_sync)
    mean_person_punishment_tACS_sync.append(person_punishment_tACS_sync)
    
    mean_person_baseline_tRNS_rTPJ.append(person_baseline_tRNS_rTPJ)
    mean_person_punishment_tRNS_rTPJ.append(person_punishment_tRNS_rTPJ)
    
    mean_person_baseline_tRNS_rDLPFC.append(person_baseline_tRNS_rDLPFC)
    mean_person_punishment_tRNS_rDLPFC.append(person_punishment_tRNS_rDLPFC)
    
    mean_person_baseline_sham.append(person_baseline_sham)
    mean_person_punishment_sham.append(person_punishment_sham)
    
    
    
    mean_pc_baseline_tACS_rTPJ.append(pc_baseline_tACS_rTPJ)
    mean_pc_punishment_tACS_rTPJ.append(pc_punishment_tACS_rTPJ)
    
    mean_pc_baseline_tACS_rDLPFC.append(pc_baseline_tACS_rDLPFC)
    mean_pc_punishment_tACS_rDLPFC.append(pc_punishment_tACS_rDLPFC)
    
    mean_pc_baseline_tACS_sync.append(pc_baseline_tACS_sync)
    mean_pc_punishment_tACS_sync.append(pc_punishment_tACS_sync)
    
    mean_pc_baseline_tRNS_rTPJ.append(pc_baseline_tRNS_rTPJ)
    mean_pc_punishment_tRNS_rTPJ.append(pc_punishment_tRNS_rTPJ)
    
    mean_pc_baseline_tRNS_rDLPFC.append(pc_baseline_tRNS_rDLPFC)
    mean_pc_punishment_tRNS_rDLPFC.append(pc_punishment_tRNS_rDLPFC)
    
    mean_pc_baseline_sham.append(pc_baseline_sham)
    mean_pc_punishment_sham.append(pc_punishment_sham)
# Out:
# ['006_results.tsv', '008_results.tsv', '009_results.tsv', '010_results.tsv', '011_results.tsv', '012_results.tsv', '013_results.tsv', '015_results.tsv', '016_results.tsv', '019_results.tsv', '020_results.tsv', '021_results.tsv', '023_results.tsv']

# %%
from scipy import stats

def getData(data):
    allData = []
    myData = np.array(data)
    myDataFormatted = np.nan_to_num(myData)
    print ('standard error mean:'); print(stats.sem(myDataFormatted))
    print ('standard deviation:'); print(np.std(myDataFormatted))
    print ('Participant Mean: ')
    participant_means = sum(myDataFormatted)/len(myDataFormatted)
    print (participant_means)
    print ('\n')
# 1
getData(mean_pc_baseline_sham)

#2
getData(mean_pc_punishment_sham)
# Out:
# standard error mean:
# 7.241456459182097
# standard deviation:
# 25.085141016202428
# Participant Mean:
# 23.525641025641026
#
#
# standard error mean:
# 4.905718596769523
# standard deviation:
# 16.993907714480624
# Participant Mean:
# 59.102564102564095

# %%
#person
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
plt.rcParams["font.family"] = "Arial"

# %%
# "tACS_rTPJ","tACS_rDLPFC","tACS_Sync","tRNS_rTPJ","tRNS_rDLPFC","Sham"
N = 6
mean_person_baseline = (31.55128205, 25.93589744, 31.47435897, 27.17948718, 33.65384615, 25.70512821)
mean_person_punishment = (61.44871795, 61.29487179, 57.42307692, 60.5, 58.84615385, 63.37179487)

sme_person_baseline = (6.714289961, 4.302633629, 6.79622628, 5.695954403, 5.35094786, 6.256397121)
sme_person_punishment = (4.114605725, 3.911874403, 4.491389966, 4.576432256, 4.426531538, 4.526518643)

# %%
ind = np.arange(N)  # the x locations for the groups
width = 0.35 

ig, ax = plt.subplots()
plot1 = ax.bar(ind, mean_person_baseline, width, color='r', yerr=sme_person_baseline, edgecolor='black')
plot2 = ax.bar(ind + width, mean_person_punishment, width, color='y', yerr=sme_person_punishment, edgecolor='black')

ax.set_ylabel('Money Units Transferred')
ax.set_title('Social')
ax.set_xticks(ind + width/2)
ax.set_xticklabels(('tACS rTPJ', 'tACS rDLPFC', 'tACS Sync', 'tRNS rTPJ', 'tRNS rDLPFC', 'Sham'))
ax.legend((plot1[0], plot2[0]),('Baseline', 'Punishment'), prop={'size': 8})
plt.locator_params(axis='y', nbins=5)
plt.ylim([0, 80])
ax = plt.gca()
ax.tick_params(axis = 'x', which = 'major', labelsize = 8)
def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('social_norms.pdf', dpi=100)
plt.show()

# %%
# "tACS_rTPJ","tACS_rDLPFC","tACS_Sync","tRNS_rTPJ","tRNS_rDLPFC","Sham"
N = 6
mean_pc_baseline = (25.6025641, 20.35897436, 24.33333333, 22.35897436, 23, 23.52564103)
mean_pc_punishment = (62.84615385, 58.20512821, 57.93589744, 50.66666667, 56.15384615, 59.1025641)

sme_pc_baseline = (7.483589322, 5.074721097, 7.71251619, 6.441575202, 5.262348116, 7.241456459)
sme_pc_punishment = (5.801299759, 5.025510202, 5.210509407, 6.670511712, 5.065330372, 4.905718597)

# %%
ind = np.arange(N)  # the x locations for the groups
width = 0.35 

ig, ax = plt.subplots()
plot1 = ax.bar(ind, mean_pc_baseline, width, color='r', yerr=sme_pc_baseline, edgecolor='black')
plot2 = ax.bar(ind + width, mean_pc_punishment, width, color='y', yerr=sme_pc_punishment, edgecolor='black')

ax.set_ylabel('Money Units Transferred')
ax.set_title('Nonsocial')
ax.set_xticks(ind + width/2)
ax.set_xticklabels(('tACS rTPJ', 'tACS rDLPFC', 'tACS Sync', 'tRNS rTPJ', 'tRNS rDLPFC', 'Sham'))
ax.legend((plot1[0], plot2[0]),('Baseline', 'Punishment'), prop={'size': 8})
plt.locator_params(axis='y', nbins=5)
plt.ylim([0, 80])
ax = plt.gca()
ax.tick_params(axis = 'x', which = 'major', labelsize = 8)
def autolabel(rects):
    """
    Attach a text label above each bar displaying its height
    """
    for rect in rects:
        height = rect.get_height()
        ax.text(rect.get_x() + rect.get_width()/2., 1.05*height,
                '%d' % int(height),
                ha='center', va='bottom')
fig1 = plt.gcf()
plt.show()
plt.draw()
fig1.savefig('pc_norms.pdf', dpi=100)
plt.show()
